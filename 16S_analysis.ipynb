# %%
#!pip install biom-format
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 9.0 MB/s eta 0:00:00a 0:00:01
# ...

# %%
import biom #-format
from biom import load_table
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

sample_data = load_table('emp_cr_silva_16S_123.release1.biom')

# %%
print(sample_data)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(sample_data)
#
# File /opt/anaconda3/envs/jupyterlab-3.6.8/lib/python3.11/site-packages/biom/table.py:1632, in Table.__str__(self)
#    1627 def __str__(self):
#    1628     """Stringify self
#    1629
#    1630     Default str output for a Table is just row/col ids and data values
#    1631     """
# -> 1632     return self.delimited_self()
#
# File /opt/anaconda3/envs/jupyterlab-3.6.8/lib/python3.11/site-packages/biom/table.py:1755, in Table.delimited_self(self, delim, header_key, header_value, metadata_formatter, observation_column_name, direct_io)
#    1751 end_line = '' if direct_io is None else '\n'
#    1753 for obs_id, obs_values in zip(iterable,
#    1754                               self._iter_obs()):
# -> 1755     str_obs_vals = delim.join(map(str, self._to_dense(obs_values)))
# ...
